# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
#import warnings
#warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
#df = pd.read_csv('table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv', low_memory=False)
df = pd.read_csv('NEW_YORK-Offenses_Known_to_Law_Enforcement_by_City_2013 - 13tbl8ny.csv',low_memory=False, header=None)
regr = linear_model.LinearRegression()

# %%
#df=df.drop([df.columns[[0, 2]]], axis=1, inplace=True)
#df.drop(df.columns[[0,2]], axis=1, inplace=True)
df.drop(df.iloc[: ,0:4], inplace=True, axis=0)
df.columns = df.iloc[0]
df.drop(df.index[:1], inplace=True)
display(df.head())
# Out:
# 4                      City Population Violent\ncrime  \
# 5             Adams Village      1,861              0
# 6  Addison Town and Village      2,577              3
# 7             Akron Village      2,846              3
# 8                    Albany     97,956            791
# 9            Albion Village      6,388             23
#
# 4 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 5                                      0                          NaN
# 6                                      0                          NaN
# 7                                      0                          NaN
# 8                                      8                          NaN
# 9                                      0                          NaN
#
# 4 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 5                           0       0                   0              12
# ...

# %%
#df['Nordic'] = np.where((df['Robbery'].isin([lambda x: x[>0: ]])), 1, 0)
#print(pd.crosstab(df['Nordic'], df['Robbery']))
#df.loc[:, 'A'].replace([1, 3, 2], [3, 6, 7], inplace=True)

#le = LabelEncoder()
#df["Robbery"] = df["Robbery"].apply(lambda Robbery: le.fit_transform["Robbery"])
df["Robbery"] = df["Robbery"].apply(lambda x: x[ : ]])), 1, 0)
# Out:
#   File "<ipython-input-59-770c43f72aff>", line 7
#     df["Robbery"] = df["Robbery"].apply(lambda x: x[!=0: ]])), 1, 0)
#                                                      ^
# SyntaxError: invalid syntax

# %%
df.head(100)
# Out:
# 4                        City Population Violent\ncrime  \
# 5               Adams Village      1,861              0
# 6    Addison Town and Village      2,577              3
# 7               Akron Village      2,846              3
# 8                      Albany     97,956            791
# 9              Albion Village      6,388             23
# 10             Alfred Village      4,089              5
# 11           Allegany Village      1,781              3
# 12               Amherst Town    118,296            107
# 13         Amityville Village      9,519              9
# 14                  Amsterdam     18,182             30
# 15             Arcade Village      2,053              0
# 16            Ardsley Village      4,523              5
# 17          Asharoken Village        658              0
# 18             Attica Village      2,522              2
# 19                     Auburn     27,270             96
# 20               Avon Village      3,333              1
# ...

# %%
df = df.loc[:, df.columns.duplicated()]

# %%
df.dtypes
# Out:
# Series([], dtype: object)

# %%
df["Property crime"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Property crime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-e79e8dde7684> in <module>()
# ...

# %%
y = df["Property crime"]
x = df["Population"]

#plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Property crime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-853f6c1d1577> in <module>()
# ...

# %%
regr = linear_model.LinearRegression()
regr.fit(x, y)

# %%
print(

# %%
plt.scatter(x, y, color='black')
plt.plot(y, regr.predict(y), color='blue', linewidth=3)
plt.show()
